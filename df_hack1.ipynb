# %% [markdown]
# This file contains the code of splitting the duplication dataset and efinetuning the model

# %%
# !pip install timm albumentations torch torchvision
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.20)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.35.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.11.10)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.2.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2025.10.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Out:
# Archive:  /content/drive/MyDrive/processed_faces_duplication.zip
#    creating: /content/content/processed_faces/duplication/
#    creating: /content/content/processed_faces/duplication/n000228/
#   inflating: /content/content/processed_faces/duplication/n000228/0400_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0488_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0277_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0069_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0223_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0566_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0495_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0291_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0479_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0257_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0394_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0131_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0192_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0088_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0226_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0407_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0272_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0122_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0063_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0054_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0081_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0270_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0526_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0202_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0164_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0070_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0119_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0103_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0232_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0235_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0013_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0068_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0234_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0398_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0338_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0338_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0212_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0298_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0320_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0577_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0244_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0265_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0292_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0042_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0473_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0284_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0377_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000228/0177_02.jpg
#    creating: /content/content/processed_faces/duplication/n000183/
#   inflating: /content/content/processed_faces/duplication/n000183/0177_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0251_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0156_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0029_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0030_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0362_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0236_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0327_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0262_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0061_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0103_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0216_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0053_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0047_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0154_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0074_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0198_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0044_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0201_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0120_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0191_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0184_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0134_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0040_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0047_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0006_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0035_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0286_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0281_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0008_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0215_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0090_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0207_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0124_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0143_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0157_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0158_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0218_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0187_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0010_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0128_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0263_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0046_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0226_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000183/0121_01.jpg
#    creating: /content/content/processed_faces/duplication/n000470/
#   inflating: /content/content/processed_faces/duplication/n000470/0110_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0055_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0078_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0083_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0011_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0005_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0030_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0079_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0061_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0118_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0018_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0105_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0063_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0022_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0088_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0216_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0007_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0013_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0109_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0128_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0064_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0070_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0086_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0056_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0112_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0048_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0040_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0020_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0047_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0111_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0182_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0272_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0008_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0122_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0080_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0043_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0027_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0115_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0108_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0042_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0039_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0137_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0024_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0267_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000470/0119_02.jpg
#    creating: /content/content/processed_faces/duplication/n000399/
#   inflating: /content/content/processed_faces/duplication/n000399/0496_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0521_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0246_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0204_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0156_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0142_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0354_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0395_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0283_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0194_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0464_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0419_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0269_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0426_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0052_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0382_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0420_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0273_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0003_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0349_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0213_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0128_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0326_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0029_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0392_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0232_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0023_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0020_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0202_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0114_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0504_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0372_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0015_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0051_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0545_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0145_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0571_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0574_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0073_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0429_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0039_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0277_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0536_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0522_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0312_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000399/0111_01.jpg
#    creating: /content/content/processed_faces/duplication/n000042/
#   inflating: /content/content/processed_faces/duplication/n000042/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0054_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0168_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0029_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0356_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0163_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0212_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0037_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0156_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0216_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0020_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0440_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0426_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0131_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0091_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0415_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0045_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0162_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0186_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0007_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0074_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0004_05.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0034_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0202_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0128_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0164_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0086_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0134_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0137_06.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0442_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0173_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0115_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0414_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0432_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0015_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0008_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0143_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0165_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0125_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0187_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0071_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0199_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0200_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0093_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0072_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0232_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0132_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0309_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000042/0111_01.jpg
#    creating: /content/content/processed_faces/duplication/n000096/
#   inflating: /content/content/processed_faces/duplication/n000096/0369_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0491_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0094_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0514_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0178_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0498_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0547_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0245_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0175_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0507_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0512_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0180_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0061_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0344_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0499_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0035_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0508_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0081_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0056_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0527_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0292_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0197_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0540_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0182_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0407_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0335_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0378_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0319_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0176_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0118_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0185_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0014_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0505_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0240_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0048_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0021_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0543_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0031_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0098_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0215_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0074_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0190_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0041_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0219_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0121_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0276_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000096/0111_05.jpg
#    creating: /content/content/processed_faces/duplication/n000164/
#   inflating: /content/content/processed_faces/duplication/n000164/0428_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0177_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0110_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0295_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0029_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0291_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0079_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0327_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0315_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0264_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0055_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0076_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0063_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0211_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0288_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0378_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0095_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0074_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0172_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0064_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0109_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0096_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0014_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0279_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0154_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0433_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0272_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0253_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0059_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0008_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0389_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0143_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0447_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0108_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0009_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0099_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0104_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0333_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0161_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0187_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0042_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0093_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0218_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0121_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0303_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000164/0166_01.jpg
#    creating: /content/content/processed_faces/duplication/n000102/
#   inflating: /content/content/processed_faces/duplication/n000102/0149_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0406_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0117_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0027_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0191_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0231_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0168_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0065_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0388_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0331_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0175_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0327_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0061_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0221_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0269_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0105_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0131_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0076_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0127_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0199_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0317_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0177_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0336_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0095_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0034_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0224_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0201_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0109_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0217_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0013_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0015_05.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0060_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0021_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0316_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0015_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0195_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0045_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0031_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0143_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0310_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0115_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0256_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0036_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0187_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0099_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0335_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0228_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000102/0121_01.jpg
#    creating: /content/content/processed_faces/duplication/n000216/
#   inflating: /content/content/processed_faces/duplication/n000216/0094_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0309_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0276_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0204_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0065_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0083_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0005_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0291_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0252_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0236_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0118_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0324_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0308_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0022_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0045_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0162_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0353_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0211_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0354_06.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0378_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0367_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0034_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0193_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0224_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0329_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0019_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0205_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0104_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0235_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0296_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0089_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0200_05.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0069_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0338_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0051_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0124_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0298_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0192_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0073_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0098_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0265_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0039_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0292_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0132_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0267_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0219_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000216/0377_01.jpg
#    creating: /content/content/processed_faces/duplication/n000474/
#   inflating: /content/content/processed_faces/duplication/n000474/0239_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0189_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0049_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0133_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0168_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0025_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0016_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0665_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0005_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0037_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0059_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0192_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0053_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0073_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0126_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0102_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0239_08.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0045_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0122_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0003_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0123_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0167_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0014_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0184_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0146_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0205_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0101_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0209_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0044_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0013_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0092_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0115_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0182_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0256_11.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0137_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0650_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0004_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0036_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0180_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0107_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0645_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0141_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0039_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0028_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0240_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0219_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0647_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000474/0166_01.jpg
#    creating: /content/content/processed_faces/duplication/n000260/
#   inflating: /content/content/processed_faces/duplication/n000260/0177_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0150_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0178_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0191_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0332_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0245_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0175_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0026_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0321_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0327_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0032_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0468_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0426_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0455_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0063_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0308_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0403_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0282_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0412_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0407_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0108_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0083_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0319_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0193_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0084_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0380_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0329_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0164_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0109_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0056_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0023_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0428_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0144_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0101_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0047_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0347_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0055_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0240_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0165_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0320_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0222_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0419_12.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0071_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0093_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0120_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0299_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0219_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0012_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0242_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000260/0477_01.jpg
#    creating: /content/content/processed_faces/duplication/n000437/
#   inflating: /content/content/processed_faces/duplication/n000437/0198_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0110_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0183_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0352_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0061_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0011_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0041_10.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0138_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0143_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0383_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0091_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0067_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0063_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0199_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0095_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0007_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0034_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0123_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0193_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0082_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0084_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0128_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0070_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0019_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0206_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0056_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0147_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0023_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0285_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0364_04.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0144_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0171_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0006_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0092_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0068_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0048_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0015_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0124_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0043_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0041_08.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0093_08.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0353_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0010_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0114_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0039_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000437/0160_01.jpg
#    creating: /content/content/processed_faces/duplication/n000166/
#   inflating: /content/content/processed_faces/duplication/n000166/0149_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0309_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0231_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0178_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0125_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0399_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0191_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0374_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000166/0039_02.jpg
# ...
#   inflating: /content/content/processed_faces/duplication/n000442/0196_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000442/0299_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000442/0121_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000442/0255_01.jpg
#    creating: /content/content/processed_faces/duplication/n000010/
#   inflating: /content/content/processed_faces/duplication/n000010/0097_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0098_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0027_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0058_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0276_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0055_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0069_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0065_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0025_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0005_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0028_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0035_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0050_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0053_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0067_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0138_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0076_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0022_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0052_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0275_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0086_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0095_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0007_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0123_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0084_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0044_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0019_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0014_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0033_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0112_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0040_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0013_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0068_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0059_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0008_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0015_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0051_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0124_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0031_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0043_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0099_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0100_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0131_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0135_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0284_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0046_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0041_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000010/0012_01.jpg
#    creating: /content/content/processed_faces/duplication/n000100/
#   inflating: /content/content/processed_faces/duplication/n000100/0331_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0340_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0278_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0307_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0388_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0332_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0411_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0356_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0219_05.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0129_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0285_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0050_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0371_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0070_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0056_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0074_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0123_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0075_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0198_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0452_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0139_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0237_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0201_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0265_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0266_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0453_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0304_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0040_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0417_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0491_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0171_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0273_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0297_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0372_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0182_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0140_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0499_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0432_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0101_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0260_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0043_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0244_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0100_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0114_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0200_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0196_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0042_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000100/0288_02.jpg
#    creating: /content/content/processed_faces/duplication/n000419/
#   inflating: /content/content/processed_faces/duplication/n000419/0514_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0188_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0125_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0262_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0582_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0352_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0156_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0011_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0507_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0411_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0005_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0227_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0395_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0257_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0499_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0087_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0091_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0391_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0282_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0076_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0558_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0579_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0281_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0671_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0068_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0485_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0726_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0137_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0326_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0670_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0101_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0616_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0696_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0052_09.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0090_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0287_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0272_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0432_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0260_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0625_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0229_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0108_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0483_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0263_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0473_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0509_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0299_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0303_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000419/0449_02.jpg
#    creating: /content/content/processed_faces/duplication/n000303/
#   inflating: /content/content/processed_faces/duplication/n000303/0097_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0038_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0081_06.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0079_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0085_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0061_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0156_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0118_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0050_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0068_08.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0073_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0022_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0066_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0162_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0095_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0007_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0123_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0064_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0176_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0070_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0056_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0147_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0087_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0113_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0040_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0101_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0100_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0048_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0195_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0143_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0253_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0036_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0033_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0145_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0102_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0159_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0077_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0010_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0151_03.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0054_02.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0042_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0093_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0046_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0041_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0121_01.jpg
#   inflating: /content/content/processed_faces/duplication/n000303/0166_01.jpg

# %%
import itertools
import random
import pandas as pd
import os

dup_base = "/content/content/processed_faces/duplication"

# -------------------
# 1️⃣ Get identities with at least 2 images
# -------------------
def get_images(person_dir):
    """Return list of valid images in a folder."""
    return [f for f in os.listdir(person_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

identities = []
for d in os.listdir(dup_base):
    person_dir = os.path.join(dup_base, d)
    imgs = get_images(person_dir)
    if os.path.isdir(person_dir) and len(imgs) >= 2:  # need at least 2 images for positive pairs
        identities.append(d)

print(f"✅ Found {len(identities)} valid identities")

# -------------------
# 2️⃣ Positive pairs
# -------------------
max_pos_per_identity = 50  # limit number of positive pairs per person
pairs = []

for person in identities:
    person_dir = os.path.join(dup_base, person)
    imgs = [os.path.join(person_dir, i) for i in get_images(person_dir)]

    # All combinations of 2 images
    all_combinations = list(itertools.combinations(imgs, 2))

    # Sample up to max_pos_per_identity
    sampled_combinations = random.sample(all_combinations, min(len(all_combinations), max_pos_per_identity))

    for a, b in sampled_combinations:
        pairs.append([a, b, 1])  # 1 = same person

print(f"✅ Created {len(pairs)} positive pairs")

# -------------------
# 3️⃣ Negative pairs (different identities)
# -------------------
num_neg = len(pairs)  # balance negatives
neg_count = 0

while neg_count < num_neg:
    id1, id2 = random.sample(identities, 2)
    imgs1 = get_images(os.path.join(dup_base, id1))
    imgs2 = get_images(os.path.join(dup_base, id2))

    if len(imgs1) == 0 or len(imgs2) == 0:
        continue  # skip empty folders

    img1 = os.path.join(dup_base, id1, random.choice(imgs1))
    img2 = os.path.join(dup_base, id2, random.choice(imgs2))

    pairs.append([img1, img2, 0])  # 0 = different person
    neg_count += 1

# -------------------
# 4️⃣ Save CSV
# -------------------
pairs_df = pd.DataFrame(pairs, columns=["img1", "img2", "label"])
pairs_df.to_csv("identity_pairs.csv", index=False)

print(f"✅ Saved identity_pairs.csv with {len(pairs_df)} total pairs")
# Out:
# ✅ Found 100 valid identities
# ✅ Created 5000 positive pairs
# ✅ Saved identity_pairs.csv with 10000 total pairs

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, val_df = train_test_split(
    pairs_df,
    test_size=0.2,
    random_state=42,
    stratify=pairs_df['label']  # maintain balance of positives/negatives
)

train_df.to_csv("identity_pairs_train.csv", index=False)
val_df.to_csv("identity_pairs_val.csv", index=False)

print(f"✅ Saved identity_pairs_train.csv ({len(train_df)}) and identity_pairs_val.csv ({len(val_df)})")
# Out:
# ✅ Saved identity_pairs_train.csv (8000) and identity_pairs_val.csv (2000)

# %%
import torch
from torch.utils.data import Dataset
import pandas as pd
import cv2
import os
import numpy as np

class IdentityPairsDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (str): Path to CSV file with columns: img1, img2, label
            transform (callable, optional): Optional transform to be applied on a sample
        """
        self.pairs_df = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.pairs_df)

    def __getitem__(self, idx):
        row = self.pairs_df.iloc[idx]
        img1_path = row['img1']
        img2_path = row['img2']
        label = int(row['label'])

        # Read images with OpenCV (BGR -> RGB)
        img1 = cv2.cvtColor(cv2.imread(img1_path), cv2.COLOR_BGR2RGB)
        img2 = cv2.cvtColor(cv2.imread(img2_path), cv2.COLOR_BGR2RGB)

        # Fallback in case image failed to load
        if img1 is None or img2 is None:
             # Return None or raise an error, depending on desired behavior
             # For now, we'll skip this sample by returning None.
             # The DataLoader will handle filtering None values if collate_fn is adjusted,
             # or we can implement a custom collate_fn.
             # For simplicity, let's raise an error for now.
             raise ValueError(f"Image not found: {img1_path} or {img2_path}")


        # Apply transforms if provided
        if self.transform:
            augmented = self.transform(image=img1)
            img1 = augmented['image']
            augmented = self.transform(image=img2)
            img2 = augmented['image']
        else:
            # Default: resize to 224x224 and convert to float32 tensor
            img1 = cv2.resize(img1, (224, 224)).astype(np.float32) / 255.0
            img2 = cv2.resize(img2, (224, 224)).astype(np.float32) / 255.0
            # HWC -> CHW
            img1 = torch.tensor(img1.transpose(2, 0, 1))
            img2 = torch.tensor(img2.transpose(2, 0, 1))

        # Convert image tensors to float32
        img1 = img1.float()
        img2 = img2.float()

        return img1, img2, torch.tensor(label, dtype=torch.float32)

# %%
from torch.utils.data import DataLoader

# Optional: Albumentations transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2

transform = A.Compose([
    A.Resize(224, 224),
    ToTensorV2()
])

# %%
from torch.utils.data import DataLoader

train_dataset = IdentityPairsDataset("identity_pairs_train.csv", transform=transform)
val_dataset = IdentityPairsDataset("identity_pairs_val.csv", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)

# %%
import torch.nn as nn
import timm

class ViTSiamese(nn.Module):
    def __init__(self, backbone_name="vit_base_patch16_224", pretrained=True, embedding_dim=512):
        super(ViTSiamese, self).__init__()
        self.backbone = timm.create_model(backbone_name, pretrained=pretrained)
        self.backbone.reset_classifier(0)  # remove original classifier
        self.fc = nn.Linear(self.backbone.num_features, embedding_dim)

    def forward_one(self, x):
        x = self.backbone(x)
        x = self.fc(x)
        x = nn.functional.normalize(x, p=2, dim=1)  # L2 normalize
        return x

    def forward(self, x1, x2):
        emb1 = self.forward_one(x1)
        emb2 = self.forward_one(x2)
        return emb1, emb2

# %%
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super().__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = nn.functional.pairwise_distance(output1, output2)
        loss = torch.mean(
            label * torch.pow(euclidean_distance, 2) +
            (1 - label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )
        return loss

# %%
from torch.utils.data import DataLoader
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_dataset = IdentityPairsDataset("identity_pairs_train.csv", transform=transform)
val_dataset   = IdentityPairsDataset("identity_pairs_val.csv", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader   = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)

model = ViTSiamese().to(device)
criterion = ContrastiveLoss(margin=1.0)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for img1, img2, labels in train_loader:
        img1, img2, labels = img1.to(device), img2.to(device), labels.to(device)
        optimizer.zero_grad()
        emb1, emb2 = model(img1, img2)
        loss = criterion(emb1, emb2, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

    # Validation
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for img1, img2, labels in val_loader:
            img1, img2, labels = img1.to(device), img2.to(device), labels.to(device)
            emb1, emb2 = model(img1, img2)
            loss = criterion(emb1, emb2, labels)
            val_loss += loss.item()
        val_loss /= len(val_loader)
        print(f"Validation Loss: {val_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Epoch [1/10], Loss: 0.2482
# Validation Loss: 0.2279
# Epoch [2/10], Loss: 0.2277
# Validation Loss: 0.2264
# Epoch [3/10], Loss: 0.2176
# Validation Loss: 0.2199
# Epoch [4/10], Loss: 0.2088
# Validation Loss: 0.2210
# Epoch [5/10], Loss: 0.1994
# Validation Loss: 0.2310
# Epoch [6/10], Loss: 0.1897
# Validation Loss: 0.2186
# Epoch [7/10], Loss: 0.1825
# Validation Loss: 0.2132
# Epoch [8/10], Loss: 0.1785
# Validation Loss: 0.2126
# Epoch [9/10], Loss: 0.1674
# Validation Loss: 0.2044
# Epoch [10/10], Loss: 0.1609
# Validation Loss: 0.2116

# %%
def compute_similarity(model, img1_path, img2_path, transform):
    model.eval()

    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    if img1 is None:
        print(f"Error: Image not found at {img1_path}")
        return None
    if img2 is None:
        print(f"Error: Image not found at {img2_path}")
        return None

    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

    # Apply transforms, convert to float, and normalize
    img1 = transform(image=img1)['image'].unsqueeze(0).to(device).float() / 255.0
    img2 = transform(image=img2)['image'].unsqueeze(0).to(device).float() / 255.0


    with torch.no_grad():
        emb1, emb2 = model(img1, img2)
        score = nn.functional.cosine_similarity(emb1, emb2).item()
    return score

score = compute_similarity(model, "/content/org.jpeg", "/content/live.jpeg", transform)
if score is not None:
    print("Similarity:", score)
# Out:
# Similarity: 0.9834152460098267

# %% [markdown]
# for 500 samples of .csv file

# %%
import torch
import torch.nn as nn
import cv2
import pandas as pd
from tqdm import tqdm

# Assuming your model and transform are already defined
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()

# --------------------------
# Similarity function
# --------------------------
def compute_similarity(model, img1_path, img2_path, transform):
    model.eval()

    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    if img1 is None or img2 is None:
        print(f"⚠️ Missing image: {img1_path} or {img2_path}")
        return None

    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

    img1 = transform(image=img1)['image'].unsqueeze(0).to(device).float() / 255.0
    img2 = transform(image=img2)['image'].unsqueeze(0).to(device).float() / 255.0

    with torch.no_grad():
        emb1, emb2 = model(img1, img2)
        score = nn.functional.cosine_similarity(emb1, emb2).item()
    return score


# --------------------------
# Load CSV
# --------------------------
csv_path = "/content/identity_pairs_val.csv"  # change as needed
df = pd.read_csv(csv_path)

if not all(col in df.columns for col in ["img1", "img2", "label"]):
    raise ValueError("CSV must have columns: img1, img2, label")

# --------------------------
# Compute similarity for 500 rows
# --------------------------
subset_df = df.head(500).copy()
scores = []

for _, row in tqdm(subset_df.iterrows(), total=len(subset_df)):
    sim = compute_similarity(model, row["img1"], row["img2"], transform)
    scores.append(sim if sim is not None else 0.0)

subset_df["similarity"] = scores

# --------------------------
# Summary metrics
# --------------------------
same_person = subset_df[subset_df["label"] == 1]["similarity"]
diff_person = subset_df[subset_df["label"] == 0]["similarity"]

print("\n✅ Results Summary:")
print(f"Total pairs processed: {len(subset_df)}")
print(f"Average similarity (same person): {same_person.mean():.4f}")
print(f"Average similarity (different persons): {diff_person.mean():.4f}")

# --------------------------
# Save to CSV
# --------------------------
subset_df.to_csv("similarity_results_500.csv", index=False)
print("✅ Saved results to similarity_results_500.csv")
# Out:
# 100%|██████████| 500/500 [00:16<00:00, 29.93it/s]
# ✅ Results Summary:
# Total pairs processed: 500
# Average similarity (same person): 0.9823
# Average similarity (different persons): 0.9761
# ✅ Saved results to similarity_results_500.csv

# %%
import pandas as pd
import numpy as np
import cv2
from insightface.app import FaceAnalysis
from tqdm import tqdm

# Initialize InsightFace model
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(224, 224))

def face_similarity(img1_path, img2_path):
    """Compute cosine similarity between two faces."""
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    if img1 is None or img2 is None:
        print(f"⚠️ Missing image: {img1_path} or {img2_path}")
        return None

    faces1 = app.get(img1)
    faces2 = app.get(img2)

    if not faces1 or not faces2:
        # No detected face
        return None

    emb1 = faces1[0]['embedding']
    emb2 = faces2[0]['embedding']

    sim = np.dot(emb1, emb2) / (np.linalg.norm(emb1) * np.linalg.norm(emb2))
    return sim


# ================================
# 1️⃣ Load CSV and sample 200 pairs
# ================================
csv_path = "identity_pairs_val.csv"  # change if needed
df = pd.read_csv(csv_path)

# Sample 200 pairs randomly
df_sample = df.sample(n=200, random_state=42).reset_index(drop=True)

# ================================
# 2️⃣ Compute similarity scores
# ================================
similarities = []
for idx, row in tqdm(df_sample.iterrows(), total=len(df_sample), desc="Processing pairs"):
    sim = face_similarity(row['img1'], row['img2'])
    if sim is not None:
        similarities.append((row['img1'], row['img2'], row['label'], sim))

# Convert to DataFrame
results_df = pd.DataFrame(similarities, columns=["img1", "img2", "label", "similarity"])
results_df.to_csv("similarity_results_200.csv", index=False)

# ================================
# 3️⃣ Compute summary statistics
# ================================
same_scores = results_df[results_df['label'] == 1]['similarity']
diff_scores = results_df[results_df['label'] == 0]['similarity']

print("\n✅ Total pairs processed:", len(results_df))
print(f"Average similarity (same person): {same_scores.mean():.4f}")
print(f"Average similarity (different persons): {diff_scores.mean():.4f}")
print("📁 Results saved to similarity_results.csv")
# Out:
# download_path: /root/.insightface/models/buffalo_l
# Downloading /root/.insightface/models/buffalo_l.zip from https://github.com/deepinsight/insightface/releases/download/v0.7/buffalo_l.zip...
# 100%|██████████| 281857/281857 [00:11<00:00, 25527.58KB/s]
# /usr/local/lib/python3.12/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (224, 224)
# Processing pairs: 100%|██████████| 200/200 [02:59<00:00,  1.12it/s]
# ✅ Total pairs processed: 198
# Average similarity (same person): 0.5127
# Average similarity (different persons): 0.0028
# 📁 Results saved to similarity_results.csv

# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 101.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.23.1
